# %%
import pandas as pd 
import numpy as numpy

# %%
s1 = pd.Series([1,2,3])

# %%
s1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s1[0]
# Out:
# 1

# %%
s1[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s2 = pd.Series([1,2,3], index=[1,2,3])

# %%
s2
# Out:
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
s2.values
# Out:
# array([1, 2, 3])

# %%
df1 = {"names":["sonic","shikki"],
       "rol_no": [1,2]}
df1
# Out:
# {'names': ['sonic', 'shikki'], 'rol_no': [1, 2]}

# %%
df1.keys()
# Out:
# dict_keys(['names', 'rol_no'])

# %%
df1.values()
# Out:
# dict_values([['sonic', 'shikki'], [1, 2]])

# %%
df1.items()
# Out:
# dict_items([('names', ['sonic', 'shikki']), ('rol_no', [1, 2])])

# %%
df2 = pd.DataFrame(s1)
df1 = pd.DataFrame(df1)

# %%
df3 = pd.concat((df1,df2),axis =1)
df3
# Out:
#     names  rol_no  0
# 0   sonic     1.0  1
# 1  shikki     2.0  2
# 2     NaN     NaN  3

# %%
df3.set_index("rol_no")
# Out:
#          names  0
# rol_no
# 1.0      sonic  1
# 2.0     shikki  2
# NaN        NaN  3

# %%
cardata = pd.read_csv("./cardata.csv")
cardata
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
cardata["Loss"] = cardata["Selling_Price"] - cardata["Present_Price"]
cardata
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Loss
# 0        Dealer       Manual      0 -2.24
# ...

# %%
cardata[cardata["Year"] == 2014]
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                    ritz  2014           3.35          5.590       27000
# 4                   swift  2014           4.60          6.870       42450
# 23               alto k10  2014           2.50          3.460       45280
# 32                  swift  2014           4.95          7.490       39000
# 33                 ertiga  2014           6.00          9.950       45000
# 34                  dzire  2014           5.50          8.060       45000
# 41               alto k10  2014           2.55          3.980       46706
# 43                  dzire  2014           5.50          8.060       45780
# 45                   ciaz  2014           7.50         12.040       15000
# 58                etios g  2014           4.10          6.800       39485
# 59               fortuner  2014          19.99         35.960       41000
# 62               fortuner  2014          18.75         35.960       78000
# ...

# %%
cardata.shape
# Out:
# (301, 10)

# %%
cardata[(cardata['Year']==2014)&(cardata['Loss']<-5)].shape
# Out:
# (4, 10)

# %%
cardata[(cardata['Year']==2014)&(cardata['Loss']<-5) | (cardata['Fuel_Type']=="Diesel")]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 7          s cross  2015           6.50           8.61       33429    Diesel
# 8             ciaz  2016           8.75           8.89       20273    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 279           city  2014           6.25          13.60       40126    Petrol
# 282           city  2014           8.25          14.00       63000    Diesel
# 295           city  2015           8.55          13.09       60076    Diesel
# 296           city  2016           9.50          11.60       33988    Diesel
# 299           city  2017          11.50          12.50        9000    Diesel
#
#     Seller_Type Transmission  Owner  Loss
# ...

# %%
cardata[~cardata['Car_Name'].isin(['ciaz'])]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 3          wagon r  2011           2.85           4.15        5200    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 298           city  2009           3.35          11.00       87934    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Loss
# ...

# %%
cardata.iloc[0]  #Integer Index,starts from 0
# Out:
# Car_Name           ritz
# Year               2014
# Selling_Price      3.35
# Present_Price      5.59
# Kms_Driven        27000
# Fuel_Type        Petrol
# Seller_Type      Dealer
# Transmission     Manual
# Owner                 0
# Loss              -2.24
# Name: 0, dtype: object

# %%
cardata[0:2]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner  Loss
# 0      Dealer       Manual      0 -2.24
# 1      Dealer       Manual      0 -4.79

# %%
cardata[0:2]['Car_Name']
# Out:
# 0    ritz
# 1     sx4
# Name: Car_Name, dtype: object

# %%
cardata.iloc[0,3]
# Out:
# 5.59

# %%
cardata.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# Loss             float64
# dtype: object

# %%
cardata.sort_index()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Loss
# 0        Dealer       Manual      0 -2.24
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(cardata,test_size=0.2)
test.sort_index()
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 12            ciaz  2015           7.50           9.94       15000    Petrol
# 14           dzire  2009           2.25           7.21       77427    Petrol
# 16          ertiga  2015           7.25          10.79       41678    Diesel
# 22             sx4  2011           4.40           8.01       50000    Petrol
# ..             ...   ...            ...            ...         ...       ...
# 265           jazz  2017           6.50           8.70       21200    Petrol
# 267           city  2016           8.35           9.40       19434    Diesel
# 287          amaze  2015           5.75           7.50       44000    Petrol
# 297           brio  2015           4.00           5.90       60000    Petrol
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Loss
# ...

# %%
cardata['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
